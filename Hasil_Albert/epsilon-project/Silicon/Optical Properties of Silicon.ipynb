# %% [markdown]
# # Optical Properties of Silicon

# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
plt.style.use('sci.mplstyle')
import numpy as np

# Set parameter
c = 299792458 # velocity of light (m/s)
hbar = 6.582119569e-16 # reduced Planck constant (eV.s)
eps0 = 8.854187817e-12 # vacum permittivity (F/m)

# Open and read the real part of dielectric tensor diagonal components
ener, repsx, repsy, repsz = np.loadtxt('epsr_Si.dat', unpack=True)
# Open and read the imaginary part of dielectric tensor diagonal components
ener, iepsx, iepsy, iepsz = np.loadtxt('epsi_Si.dat', unpack=True)

# Count the average of real and imaginer part components
eps1 = (repsx+repsy+repsz)/3
eps2 = (iepsx+iepsy+iepsz)/3

# %%
# Define function of n, kappa, absorption coeff., and sigma real
def refractive_index(eps1, eps2) :
    n = ((eps1 + (eps1**2+eps2**2)**(0.5))**(0.5)) / np.sqrt(0.5)
    return n

def extinction_coeff(eps1, eps2) :
    kappa = ((-eps1 + (eps1**2+eps2**2)**(0.5))**(0.5)) / np.sqrt(0.5)
    return kappa

def absorption_coeff(ener, kappa, c, hbar) :
    alpha = (2*kappa*ener)/(hbar*c)
    return alpha

def sigma_real(eps2, ener, hbar) :
    sigma = (eps2*ener)/hbar
    return sigma

# Calculate the array of our definition above
n = refractive_index(eps1, eps2)
kappa = extinction_coeff(eps1, eps2)
alpha = absorption_coeff(ener, kappa, c, hbar)
sigma = sigma_real(eps2, ener, hbar)

# %%
# Create figure object
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
# Plot the optical properties
ax[0,0].plot(ener, n, 'b-')
ax[0,1].plot(ener, kappa, 'r-')
ax[1,0].plot(ener, alpha/1.e8, 'g-')
ax[1,1].plot(ener, sigma/1.e17, color='purple')
# Add the x and y-axis labels
ax[1,0].set_xlabel('Photon energy (eV)')
ax[1,1].set_xlabel('Photon energy (eV)')
ax[0,0].set_ylabel(r'Refractive Index (n)', color='b')
ax[0,1].set_ylabel(r'Exctinction Coefficient ($\kappa$)', color='b')
ax[1,0].set_ylabel(r'$\alpha\ (10^{8}\ \mathrm{m}^{-1})$', color='b')
ax[1,1].set_ylabel(r'$\sigma$ (S/m)', color='b')
# Set the ornament
ax[0,0].set_xlim(0, 30)
ax[0,1].set_xlim(0, 30)
ax[1,0].set_xlim(0, 30)
ax[1,1].set_xlim(0, 30)
ax[0,0].set_ylim(0, 13)
ax[0,0].set_yticks([2.5, 5, 7.5, 10, 12.5])
ax[1,0].set_ylim(0, 4.3)
ax[1,0].set_yticks([1, 2, 3, 4])
ax[0,1].set_ylim(0, 12)
ax[0,1].set_yticks([2, 4, 6, 8, 10])
ax[1,1].set_ylim(0, 3.2)
ax[1,1].set_yticks([1, 2, 3])
fig.suptitle('Optical Properties of Silicon', fontsize=36)

# save figure
fig.savefig('./Graph Optical Properties Silicon.png', dpi=600)
plt.show()

# %%
import numpy as np
from OpticalProperties import *
import matplotlib.pyplot as plt

# %%
ReEpsSi = np.loadtxt('epsr_Si.dat')
ImEpsSi = np.loadtxt('epsi_Si.dat')

# %%
average_epsilon_qe(ReEpsSi, ImEpsSi, 'average_eps.dat')

# %%
average_eps_Si = np.loadtxt('average_eps.dat')
optical_properties(average_eps_Si[:,0], average_eps_Si[:,1], average_eps_Si[:,2], 'Optical_Si.dat')

# %%
# Open and read the real part of dielectric tensor diagonal components
ener_n, n_n, kappa_n, alpha_n = np.loadtxt('Optical_Si.dat', unpack=True)
# Create figure object
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
# Plot the optical properties
ax[0,0].plot(ener_n, n_n, 'b-')
ax[0,1].plot(ener_n, kappa_n, 'r-')
ax[1,0].plot(ener_n, alpha_n/1.e8, 'g-')
# ax[1,1].plot(ener_n, sigma_n/1.e17, color='purple')
# Add the x and y-axis labels
ax[1,0].set_xlabel('Photon energy (eV)')
ax[1,1].set_xlabel('Photon energy (eV)')
ax[0,0].set_ylabel(r'Refractive Index (n)', color='b')
ax[0,1].set_ylabel(r'Exctinction Coefficient ($\kappa$)', color='b')
ax[1,0].set_ylabel(r'$\alpha\ (10^{8}\ \mathrm{m}^{-1})$', color='b')
ax[1,1].set_ylabel(r'$\sigma$ (S/m)', color='b')
# Set the ornament
ax[0,0].set_xlim(0, 30)
ax[0,1].set_xlim(0, 30)
ax[1,0].set_xlim(0, 30)
ax[1,1].set_xlim(0, 30)
fig.suptitle('Optical Properties of Silicon by Pak MYHanna', fontsize=36)

# save figure
fig.savefig('./Graph Optical Properties Silicon by Pak MYHanna.png', dpi=600)
plt.show()
