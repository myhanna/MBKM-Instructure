# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'monospace'
plt.rcParams['font.size'] = 15

fig = plt.figure(figsize=[12,8])

axBnd = fig.add_axes([0.00, 0.0, 0.30, 0.4])
axDOS = fig.add_axes([0.35, 0.0, 0.15, 0.4])

prefix     = 'si'
folderBnd  = 'bands/'
folderDOS  = 'dos/'

EFermi =  6.255

#--------------------------------------------------------------#
# Bands Structure
#--------------------------------------------------------------#

nBand = 8
nkpts = 110

fBand   = open(folderBnd+prefix+'.bands.gnu', 'r')
dataBnd = [line for line in fBand.readlines() if line.strip()]
fBand.close()

kpts = []
for ik in range (nkpts):
    kpts.append(float(dataBnd[ik].split()[0]))

band = []
for ib in range (nBand):
    band.append([])
    for ik in range (nkpts):
        band[ib].append(float(dataBnd[ib*nkpts+ik].split()[-1]))
        
eBnd = []
for ik in range (nkpts):
    eBnd.append([])
    for ib in range (nBand):
        eBnd[ik].append(band[ib][ik]-EFermi)
    
axBnd.plot(kpts, eBnd, color = 'drakblue')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 38
#      36     band.append([])
#      37     for ik in range (nkpts):
# ---> 38         band[ib].append(float(dataBnd[ib*nkpts+ik].split()[-1]))
#      40 eBnd = []
#      41 for ik in range (nkpts):
#
# IndexError: list index out of range
